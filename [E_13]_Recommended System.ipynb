# %% [markdown]
# # 평가 문항
# 1. CSR matrix가 정상적으로 만들어졌다.
#     - 사용자와 아이템 개수를 바탕으로 정확한 사이즈로 만들었다.
# 2. MF 모델이 정상적으로 훈련되어 그럴듯한 추천이 이루어졌다.
#     - 사용자와 아이템 벡터 내적수치가 의미있게 형성되었다.
# 3. 비슷한 영화 찾기와 유저에게 추천하기의 과정이 정상적으로 진행되었다.
#     - MF모델이 예측한 유저 선호도 및 아이템간 유사도, 기여도를 측정하고 의미를 분석해보았다.

# %% [markdown]
# # 모듈 임포트

# %%
import numpy as np
import scipy
import implicit
import os
import pandas as pd
from implicit.als import AlternatingLeastSquares
import os
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 데이터 준비

# %% [markdown]
# ## 평점 데이터

# %%
import os
rating_file_path=os.getenv('HOME') + '/aiffel/recommendata_iu/data/ml-1m/ratings.dat'
ratings_cols = ['user_id', 'movie_id', 'ratings', 'timestamp']
ratings = pd.read_csv(rating_file_path, sep='::', names=ratings_cols, engine='python', encoding = "ISO-8859-1")
orginal_data_size = len(ratings)
ratings.head()
# Out:
#    user_id  movie_id  ratings  timestamp
# 0        1      1193        5  978300760
# 1        1       661        3  978302109
# 2        1       914        3  978301968
# 3        1      3408        4  978300275
# 4        1      2355        5  978824291

# %%
ratings.shape
# Out:
# (1000209, 4)

# %% [markdown]
# ## 영화 데이터

# %%
# 영화 제목을 보기 위해 메타 데이터를 읽어옵니다.
movie_file_path=os.getenv('HOME') + '/aiffel/recommendata_iu/data/ml-1m/movies.dat'
cols = ['movie_id', 'title', 'genre'] 
movies = pd.read_csv(movie_file_path, sep='::', names=cols, engine='python', encoding='ISO-8859-1')
movies.head()
# Out:
#    movie_id                               title                         genre
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
movies.shape
# Out:
# (3883, 3)

# %% [markdown]
# # 데이터 전처리하기
# - ratings에 있는 유니크한 영화 개수
# - ratings에 있는 유니크한 사용자 수
# - 가장 인기 있는 영화 30개(인기순)

# %% [markdown]
# #### 필요없는 컬럼 삭제

# %%
del ratings['timestamp']

# %% [markdown]
# #### 데이터 합치기

# %%
movie_data = pd.merge(ratings, movies)
movie_data.head()
# Out:
#    user_id  movie_id  ratings                                   title  genre
# 0        1      1193        5  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1        2      1193        5  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2       12      1193        4  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3       15      1193        4  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4       17      1193        5  One Flew Over the Cuckoo's Nest (1975)  Drama

# %%
movie_data.shape
# Out:
# (1000209, 5)

# %% [markdown]
# #### ratings 점수가 3점 미만인 데이터는 선호하지 않는다고 가정하고 제외

# %%
# 3점 이상만 남깁니다.
ratings = ratings[ratings['ratings']>=3]
filtered_data_size = len(ratings)

print(f'orginal_data_size: {orginal_data_size}, filtered_data_size: {filtered_data_size}')
print(f'Ratio of Remaining Data is {filtered_data_size / orginal_data_size:.2%}')

# %%
# 3점 이상만 남깁니다.
ratings3_movie_data = movie_data[movie_data['ratings']>=3]
filtered_data_size = len(ratings3_movie_data)

print(f'orginal_data_size: {orginal_data_size}, filtered_data_size: {filtered_data_size}')
print(f'Ratio of Remaining Data is {filtered_data_size / orginal_data_size:.2%}')
# Out:
# orginal_data_size: 1000209, filtered_data_size: 836478
# Ratio of Remaining Data is 83.63%

# %% [markdown]
# - ratings라는 컬럼을 좀 더 보기 편하도록 counts라는 컬럼명으로 변경

# %%
ratings3_movie_data.rename(columns={'ratings':'counts'}, inplace=True)

# %%
ratings.rename(columns={'ratings':'counts'}, inplace=True)

# %%
ratings3_movie_data['counts']
# Out:
# 0          5
# 1          5
# 2          4
# 3          4
# 4          5
#           ..
# 1000203    3
# 1000204    5
# 1000205    3
# 1000207    5
# 1000208    4
# Name: counts, Length: 836478, dtype: int64

# %%
ratings3_movie_data.head(5)
# Out:
#    user_id  movie_id  counts                                   title  genre
# 0        1      1193       5  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1        2      1193       5  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2       12      1193       4  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3       15      1193       4  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4       17      1193       5  One Flew Over the Cuckoo's Nest (1975)  Drama

# %% [markdown]
# #### 검색을 쉽게 하기 위해 영화 제목과 장르를 소문자로 바꿔줌

# %%
ratings3_movie_data['title'] = ratings3_movie_data['title'].str.lower()

# %%
ratings3_movie_data['genre'] = ratings3_movie_data['genre'].str.lower()

# %% [markdown]
# ## 데이터 탐색

# %% [markdown]
# #### ratings에 있는 user와 movie의 유니크 갯수 구해보기

# %%
ratings3_movie_data['user_id'].nunique()
# Out:
# 6039

# %%
ratings3_movie_data['movie_id'].nunique()
# Out:
# 3628

# %% [markdown]
# - 관객은 총 6039명이 존재하며, 영화는 3628개가 있음

# %% [markdown]
# #### 가장 인기 있는 영화 50개(인기순) 구해보기

# %%
ratings3_movie_data.groupby('title')['counts'].count().sort_values(ascending=False)[:50]
# Out:
# title
# american beauty (1999)                                   3211
# star wars: episode iv - a new hope (1977)                2910
# star wars: episode v - the empire strikes back (1980)    2885
# star wars: episode vi - return of the jedi (1983)        2716
# saving private ryan (1998)                               2561
# terminator 2: judgment day (1991)                        2509
# silence of the lambs, the (1991)                         2498
# raiders of the lost ark (1981)                           2473
# back to the future (1985)                                2460
# matrix, the (1999)                                       2434
# jurassic park (1993)                                     2413
# sixth sense, the (1999)                                  2385
# fargo (1996)                                             2371
# braveheart (1995)                                        2314
# men in black (1997)                                      2297
# schindler's list (1993)                                  2257
# princess bride, the (1987)                               2252
# shakespeare in love (1998)                               2213
# l.a. confidential (1997)                                 2210
# shawshank redemption, the (1994)                         2194
# godfather, the (1972)                                    2167
# groundhog day (1993)                                     2121
# e.t. the extra-terrestrial (1982)                        2102
# being john malkovich (1999)                              2066
# ghostbusters (1984)                                      2051
# pulp fiction (1994)                                      2030
# forrest gump (1994)                                      2022
# terminator, the (1984)                                   2019
# toy story (1995)                                         2000
# fugitive, the (1993)                                     1941
# alien (1979)                                             1920
# gladiator (2000)                                         1798
# total recall (1990)                                      1786
# star wars: episode i - the phantom menace (1999)         1783
# usual suspects, the (1995)                               1744
# stand by me (1986)                                       1728
# blade runner (1982)                                      1722
# aliens (1986)                                            1720
# one flew over the cuckoo's nest (1975)                   1680
# wizard of oz, the (1939)                                 1650
# godfather: part ii, the (1974)                           1624
# casablanca (1942)                                        1623
# who framed roger rabbit? (1988)                          1605
# bug's life, a (1998)                                     1599
# jaws (1975)                                              1598
# goodfellas (1990)                                        1595
# die hard (1988)                                          1593
# hunt for red october, the (1990)                         1587
# airplane! (1980)                                         1586
# babe (1995)                                              1574
# Name: counts, dtype: int64

# %% [markdown]
# - 해당 영화 데이터는 2017년 7월 또는 그 이전에 출시된 영화들로만 이루어져 있어서 옛날 영화들이 많이 보임
# - 가장 인기있는 영화는 american beauty이며, star wars 시리즈도 2-4위권에 포함되어 있음
# - 사실 나는 여기 영화중에서 매트릭스, 토이 스토리 같은 것만 제외하면 아는것이 거의 없다..

# %% [markdown]
# #### 한 영화에 대한 관객의 total 평점의 분포

# %%
ratings3_movie_data.groupby('title')['counts'].count().describe()
# Out:
# count    3628.000000
# mean      230.561742
# std       355.596393
# min         1.000000
# 25%        23.000000
# 50%        87.000000
# 75%       285.000000
# max      3211.000000
# Name: counts, dtype: float64

# %% [markdown]
# - 한 영화의 최고 total 평점은 3211점
# - 가장 작은 평점은 1점을 받았음
# - 한 영화는 평균적으로 230점의 점수를 받았음

# %% [markdown]
# #### 가장 평점이 높은 영화 30개(인기순) 구해보기

# %%
ratings3_movie_data.groupby('title')['counts'].mean().sort_values(ascending=False)[:30]
# Out:
# title
# gate of heavenly peace, the (1995)                                     5.000000
# follow the bitch (1998)                                                5.000000
# identification of a woman (identificazione di una donna) (1982)        5.000000
# schlafes bruder (brother of sleep) (1995)                              5.000000
# criminal lovers (les amants criminels) (1999)                          5.000000
# country life (1994)                                                    5.000000
# foreign student (1994)                                                 5.000000
# lured (1947)                                                           5.000000
# baby, the (1973)                                                       5.000000
# late bloomers (1996)                                                   5.000000
# zachariah (1971)                                                       5.000000
# bittersweet motel (2000)                                               5.000000
# black sunday (la maschera del demonio) (1960)                          5.000000
# song of freedom (1936)                                                 5.000000
# message to love: the isle of wight festival (1996)                     5.000000
# smashing time (1967)                                                   5.000000
# ulysses (ulisse) (1954)                                                5.000000
# paralyzing fear: the story of polio in america, a (1998)               5.000000
# one little indian (1973)                                               5.000000
# i am cuba (soy cuba/ya kuba) (1964)                                    4.800000
# seven chances (1925)                                                   4.750000
# lamerica (1994)                                                        4.750000
# sunset strip (2000)                                                    4.666667
# firelight (1997)                                                       4.666667
# apple, the (sib) (1998)                                                4.666667
# sanjuro (1962)                                                         4.647059
# seven samurai (the magnificent seven) (shichinin no samurai) (1954)    4.629690
# world of apu, the (apur sansar) (1959)                                 4.603774
# godfather, the (1972)                                                  4.598523
# shawshank redemption, the (1994)                                       4.596627
# Name: counts, dtype: float64

# %% [markdown]
# - 평점이 높은 영화와 인기가 많은 영화는 다르게 나왔음
# - 아마 인기가 많다는 것은 사람들이 그만큼 많이 보고 다양한 의견이 나오기 때문에 평균 평점이 떨어지는 것으로 생각됨
# - 평점이 높은 영화는 Ulysses, Country, Schlafes Bruder등이 있음

# %% [markdown]
# #### 1번 관객이 본 영화 알아보기

# %%
ratings3_movie_data[ratings3_movie_data['user_id']==1]
# Out:
#        user_id  movie_id  counts  \
# 0            1      1193       5
# 1725         1       661       3
# 2250         1       914       3
# 2886         1      3408       4
# 4201         1      2355       5
# 5904         1      1197       3
# 8222         1      1287       5
# 8926         1      2804       5
# 10278        1       594       4
# 11041        1       919       4
# 12759        1       595       5
# 13819        1       938       4
# 14006        1      2398       4
# 14386        1      2918       4
# 15859        1      1035       5
# 16741        1      2791       4
# 18472        1      2687       3
# 18914        1      2018       4
# 19503        1      3105       5
# 20183        1      2797       4
# 21674        1      2321       3
# 22832        1       720       3
# 23270        1      1270       5
# 25853        1       527       5
# 28157        1      2340       3
# 28501        1        48       5
# 28883        1      1097       4
# 31152        1      1721       4
# 32698        1      1545       4
# 32771        1       745       3
# 33428        1      2294       4
# 34073        1      3186       4
# 34504        1      1566       4
# 34973        1       588       4
# 36324        1      1907       4
# 36814        1       783       4
# 37204        1      1836       5
# 37339        1      1022       5
# 37916        1      2762       4
# 40375        1       150       5
# 41626        1         1       5
# 43703        1      1961       5
# 45033        1      1962       4
# 45685        1      2692       4
# 46757        1       260       4
# 49748        1      1028       5
# 50759        1      1029       5
# 51327        1      1207       4
# 52255        1      2028       5
# 54908        1       531       4
# 55246        1      3114       4
# 56831        1       608       4
# 59344        1      1246       4
#
#                                                    title  \
# 0                 one flew over the cuckoo's nest (1975)
# 1725                    james and the giant peach (1996)
# 2250                                 my fair lady (1964)
# 2886                              erin brockovich (2000)
# 4201                                bug's life, a (1998)
# 5904                          princess bride, the (1987)
# 8222                                      ben-hur (1959)
# 8926                           christmas story, a (1983)
# 10278             snow white and the seven dwarfs (1937)
# 11041                           wizard of oz, the (1939)
# 12759                        beauty and the beast (1991)
# 13819                                        gigi (1958)
# 14006                      miracle on 34th street (1947)
# 14386                    ferris bueller's day off (1986)
# 15859                         sound of music, the (1965)
# 16741                                   airplane! (1980)
# 18472                                      tarzan (1999)
# 18914                                       bambi (1942)
# 19503                                  awakenings (1990)
# 20183                                         big (1988)
# 21674                               pleasantville (1998)
# 22832  wallace & gromit: the best of aardman animatio...
# 23270                          back to the future (1985)
# 25853                            schindler's list (1993)
# 28157                              meet joe black (1998)
# 28501                                  pocahontas (1995)
# 28883                  e.t. the extra-terrestrial (1982)
# 31152                                     titanic (1997)
# 32698                                     ponette (1996)
# 32771                              close shave, a (1995)
# 33428                                        antz (1998)
# 34073                           girl, interrupted (1999)
# 34504                                    hercules (1997)
# 34973                                     aladdin (1992)
# 36324                                       mulan (1998)
# 36814                hunchback of notre dame, the (1996)
# 37204                     last days of disco, the (1998)
# 37339                                  cinderella (1950)
# 37916                            sixth sense, the (1999)
# 40375                                   apollo 13 (1995)
# 41626                                   toy story (1995)
# 43703                                    rain man (1988)
# 45033                          driving miss daisy (1989)
# 45685                   run lola run (lola rennt) (1998)
# 46757          star wars: episode iv - a new hope (1977)
# 49748                                mary poppins (1964)
# 50759                                       dumbo (1941)
# 51327                       to kill a mockingbird (1962)
# 52255                         saving private ryan (1998)
# 54908                          secret garden, the (1993)
# 55246                                 toy story 2 (1999)
# 56831                                       fargo (1996)
# 59344                          dead poets society (1989)
#
#                                                genre
# 0                                              drama
# 1725                    animation|children's|musical
# 2250                                 musical|romance
# 2886                                           drama
# 4201                     animation|children's|comedy
# 5904                 action|adventure|comedy|romance
# 8222                          action|adventure|drama
# 8926                                    comedy|drama
# 10278                   animation|children's|musical
# 11041             adventure|children's|drama|musical
# 12759                   animation|children's|musical
# 13819                                        musical
# 14006                                          drama
# 14386                                         comedy
# 15859                                        musical
# 16741                                         comedy
# 18472                           animation|children's
# 18914                           animation|children's
# 19503                                          drama
# 20183                                 comedy|fantasy
# 21674                                         comedy
# 22832                                      animation
# 23270                                  comedy|sci-fi
# 25853                                      drama|war
# 28157                                        romance
# 28501           animation|children's|musical|romance
# 28883                children's|drama|fantasy|sci-fi
# 31152                                  drama|romance
# 32698                                          drama
# 32771                      animation|comedy|thriller
# 33428                           animation|children's
# 34073                                          drama
# 34504  adventure|animation|children's|comedy|musical
# 34973            animation|children's|comedy|musical
# 36324                           animation|children's
# 36814                   animation|children's|musical
# 37204                                          drama
# 37339                   animation|children's|musical
# 37916                                       thriller
# 40375                                          drama
# 41626                    animation|children's|comedy
# 43703                                          drama
# 45033                                          drama
# 45685                           action|crime|romance
# 46757                action|adventure|fantasy|sci-fi
# 49748                      children's|comedy|musical
# 50759                   animation|children's|musical
# 51327                                          drama
# 52255                               action|drama|war
# 54908                               children's|drama
# 55246                    animation|children's|comedy
# 56831                           crime|drama|thriller
# 59344                                          drama

# %% [markdown]
# - 1번 관객은 총 53편의 영화를 봤음
# - 드라마, 뮤지컬 장르의 영화를 많이 본것으로 확인됨

# %% [markdown]
# ## 내가 좋아하는 영화 찾아보기

# %% [markdown]
# - 저는 comedy, drama 장르를 좋아하기는 하지만, 유명한 영화를 위주로 한번 찾아보도록 하겠습니다.

# %%
ratings3_movie_data[ratings3_movie_data['genre']== "animation|children's|comedy"].drop_duplicates(subset='title')[:50]
# Out:
#         user_id  movie_id  counts  \
# 4201          1      2355       5
# 41626         1         1       5
# 55246         1      3114       4
# 405723        9      3751       4
# 656928       18      2141       5
# 657332       18      2142       3
# 676614       44      1064       4
# 928719       75      2354       4
# 944202      148      3754       3
# 996385      563      3611       3
#
#                                                  title  \
# 4201                              bug's life, a (1998)
# 41626                                 toy story (1995)
# 55246                               toy story 2 (1999)
# 405723                              chicken run (2000)
# 656928                        american tail, an (1986)
# 657332      american tail: fievel goes west, an (1991)
# 676614          aladdin and the king of thieves (1996)
# 928719                       rugrats movie, the (1998)
# 944202  adventures of rocky and bullwinkle, the (2000)
# 996385                           saludos amigos (1943)
#
#                               genre
# 4201    animation|children's|comedy
# 41626   animation|children's|comedy
# 55246   animation|children's|comedy
# 405723  animation|children's|comedy
# 656928  animation|children's|comedy
# 657332  animation|children's|comedy
# 676614  animation|children's|comedy
# 928719  animation|children's|comedy
# 944202  animation|children's|comedy
# 996385  animation|children's|comedy

# %%
ratings3_movie_data[ratings3_movie_data['genre']== "action|sci-fi|thriller"].drop_duplicates(subset='title')[:50]
# Out:
#          user_id  movie_id  counts                              title  \
# 102056         2       589       4  terminator 2: judgment day (1991)
# 140405         2      2571       4                 matrix, the (1999)
# 221008        17      3527       4                    predator (1987)
# 224023         4      1240       5             terminator, the (1984)
# 349735         7      1573       4                    face/off (1997)
# 379260        17      2600       3                    existenz (1999)
# 427328        10      1831       5               lost in space (1998)
# 596260        15       748       3                arrival, the (1996)
# 622779        23      2722       3               deep blue sea (1999)
# 721095        42      1037       3          lawnmower man, the (1992)
# 844550        36       172       4             johnny mnemonic (1995)
# 849189        36      3697       4                  predator 2 (1990)
# 926145        73       692       4                        solo (1996)
# 1000201     5433       286       3           nemesis 2: nebula (1995)
#
#                           genre
# 102056   action|sci-fi|thriller
# 140405   action|sci-fi|thriller
# 221008   action|sci-fi|thriller
# 224023   action|sci-fi|thriller
# 349735   action|sci-fi|thriller
# 379260   action|sci-fi|thriller
# 427328   action|sci-fi|thriller
# 596260   action|sci-fi|thriller
# 622779   action|sci-fi|thriller
# 721095   action|sci-fi|thriller
# 844550   action|sci-fi|thriller
# 849189   action|sci-fi|thriller
# 926145   action|sci-fi|thriller
# 1000201  action|sci-fi|thriller

# %%
ratings3_movie_data[ratings3_movie_data['genre']== "crime|drama"].drop_duplicates(subset='title')[:50]
# Out:
#          user_id  movie_id  counts  \
# 64571          2      2268       5
# 74399          5      1213       5
# 106150         2      1945       5
# 114987         2      1084       3
# 146474         2      3735       3
# 231376         5      1466       3
# 240911         5       296       4
# 289423         5      1729       4
# 616162        15      1804       4
# 714353        22      1799       4
# 746341        23       431       3
# 749198        49      3741       4
# 818201        33      3019       5
# 827136        33      1061       4
# 898979        53       290       5
# 902633        53      2112       4
# 906091        58      3328       5
# 915969        62       960       4
# 931100        76      3783       4
# 945773       110      2231       4
# 952212       123      3304       3
# 956227       129      1404       4
# 956508       180      1053       3
# 965833       225      3272       4
# 967218       149       391       3
# 979130       187      2963       4
# 981939       272      3761       5
# 990005      1140      3335       4
# 992270       331      1791       3
# 992896       352       283       3
# 996628       588      3588       3
# 996908       652      2842       3
# 997163       670       850       3
# 998178       817      2332       3
# 999010      1069       245       4
# 999198      1088       962       4
# 999645      1383      3517       4
# 999957      2909       874       5
# 1000126     3945      3413       4
# 1000142     4169      3229       4
# 1000174     4766      1842       4
#
#                                                      title        genre
# 64571                               few good men, a (1992)  crime|drama
# 74399                                    goodfellas (1990)  crime|drama
# 106150                            on the waterfront (1954)  crime|drama
# 114987                             bonnie and clyde (1967)  crime|drama
# 146474                                      serpico (1973)  crime|drama
# 231376                                donnie brasco (1997)  crime|drama
# 240911                                 pulp fiction (1994)  crime|drama
# 289423                                 jackie brown (1997)  crime|drama
# 616162                             newton boys, the (1998)  crime|drama
# 714353                                suicide kings (1997)  crime|drama
# 746341                                carlito's way (1993)  crime|drama
# 749198                                     badlands (1973)  crime|drama
# 818201                             drugstore cowboy (1989)  crime|drama
# 827136                                     sleepers (1996)  crime|drama
# 898979                           once were warriors (1994)  crime|drama
# 902633                                 grand canyon (1991)  crime|drama
# 906091            ghost dog: the way of the samurai (1999)  crime|drama
# 915969                         angel on my shoulder (1946)  crime|drama
# 931100                                     croupier (1998)  crime|drama
# 945773                                     rounders (1998)  crime|drama
# 952212                                  blue collar (1978)  crime|drama
# 956227                     night falls on manhattan (1997)  crime|drama
# 956508                                  normal life (1996)  crime|drama
# 965833                               bad lieutenant (1992)  crime|drama
# 967218                                jason's lyric (1994)  crime|drama
# 979130                                 joe the king (1999)  crime|drama
# 981939   blood in, blood out (a.k.a. bound by honor) (1...  crime|drama
# 990005                                    jail bait (1954)  crime|drama
# 992270                                     twilight (1998)  crime|drama
# 992896                             new jersey drive (1995)  crime|drama
# 996628                  king of marvin gardens, the (1972)  crime|drama
# 996908                              best laid plans (1999)  crime|drama
# 997163                                        cyclo (1995)  crime|drama
# 998178                                        belly (1998)  crime|drama
# 999010                            glass shield, the (1994)  crime|drama
# 999198                      they made me a criminal (1939)  crime|drama
# 999645                                   bells, the (1926)  crime|drama
# 999957                  killer: a journal of murder (1995)  crime|drama
# 1000126                                      impact (1949)  crime|drama
# 1000142                        another man's poison (1952)  crime|drama
# 1000174                                     illtown (1996)  crime|drama

# %%
ratings3_movie_data[ratings3_movie_data['genre']== "comedy"].drop_duplicates(subset='title')[:50]
# Out:
#         user_id  movie_id  counts  \
# 14386         1      2918       4
# 16741         1      2791       4
# 21674         1      2321       3
# 61126         2      1537       4
# 138499        2      2359       3
# 148641        2      3809       3
# 182198        3      3421       4
# 183406       12      1641       3
# 184604        3      1394       4
# 186038        3      3534       3
# 186543        3       104       4
# 187916        3      3868       3
# 188608        3      1079       5
# 189934        3      2997       3
# 197991      223      3619       3
# 202877        3      3552       5
# 210642        3      1136       5
# 232096      678       860       3
# 232953        5      2770       4
# 245511        5       728       4
# 252153       23        52       4
# 260862        5      1485       3
# 271180        5      1923       3
# 275832        5       176       4
# 281466        5      2599       5
# 294366        5      1513       4
# 295206        5      2318       4
# 295526        5      1517       4
# 300216        5      1449       4
# 301857        5      2390       4
# 303816        5      2395       5
# 305343        5      2683       3
# 307072        5      2759       3
# 310026        5       348       4
# 315393       26      1966       4
# 319177        5      1171       4
# 319592        5      3786       3
# 328797        6      3072       4
# 381151        8      3481       4
# 392845        9       223       4
# 394847        9      3948       3
# 408470        9      2302       4
# 410582        9      3253       4
# 413557        9      1446       3
# 422018       10      2124       3
# 425831       10      3869       3
# 426856       10      1257       5
# 435140       10      2136       4
# 442929       10      2072       4
# 446140       10       743       3
#
#                                                     title   genre
# 14386                     ferris bueller's day off (1986)  comedy
# 16741                                    airplane! (1980)  comedy
# 21674                                pleasantville (1998)  comedy
# 61126            shall we dance? (shall we dansu?) (1996)  comedy
# 138499                           waking ned devine (1998)  comedy
# 148641                             what about bob? (1991)  comedy
# 182198                                animal house (1978)  comedy
# 183406                             full monty, the (1997)  comedy
# 184604                             raising arizona (1987)  comedy
# 186038                                     28 days (2000)  comedy
# 186543                               happy gilmore (1996)  comedy
# 187916  naked gun: from the files of police squad!, th...  comedy
# 188608                        fish called wanda, a (1988)  comedy
# 189934                        being john malkovich (1999)  comedy
# 197991                      hollywood knights, the (1980)  comedy
# 202877                                  caddyshack (1980)  comedy
# 210642             monty python and the holy grail (1974)  comedy
# 232096        maybe, maybe not (bewegte mann, der) (1994)  comedy
# 232953                                   bowfinger (1999)  comedy
# 245511                           cold comfort farm (1995)  comedy
# 252153                            mighty aphrodite (1995)  comedy
# 260862                                   liar liar (1997)  comedy
# 271180                there's something about mary (1998)  comedy
# 275832                          living in oblivion (1995)  comedy
# 281466                                    election (1999)  comedy
# 294366      romy and michele's high school reunion (1997)  comedy
# 295206                                   happiness (1998)  comedy
# 295526  austin powers: international man of mystery (1...  comedy
# 300216                         waiting for guffman (1996)  comedy
# 301857                                little voice (1998)  comedy
# 303816                                    rushmore (1998)  comedy
# 305343       austin powers: the spy who shagged me (1999)  comedy
# 307072                                        dick (1999)  comedy
# 310026                       bullets over broadway (1994)  comedy
# 315393                                metropolitan (1990)  comedy
# 319177                                 bob roberts (1992)  comedy
# 319592                       but i'm a cheerleader (1999)  comedy
# 328797                                  moonstruck (1987)  comedy
# 381151                               high fidelity (2000)  comedy
# 392845                                      clerks (1994)  comedy
# 394847                            meet the parents (2000)  comedy
# 408470                             my cousin vinny (1992)  comedy
# 410582                               wayne's world (1992)  comedy
# 413557                                       kolya (1996)  comedy
# 422018                          addams family, the (1991)  comedy
# 425831     naked gun 2 1/2: the smell of fear, the (1991)  comedy
# 426856                          better off dead... (1985)  comedy
# 435140                        nutty professor, the (1963)  comedy
# 442929                                 'burbs, the (1989)  comedy
# 446140                                    spy hard (1996)  comedy

# %%
ratings3_movie_data[ratings3_movie_data['title']== 'shall we dance? (shall we dansu?) (1996)']
# Out:
#        user_id  movie_id  counts                                     title  \
# 61126        2      1537       4  shall we dance? (shall we dansu?) (1996)
# 61127       28      1537       4  shall we dance? (shall we dansu?) (1996)
# 61128       45      1537       3  shall we dance? (shall we dansu?) (1996)
# 61129       59      1537       3  shall we dance? (shall we dansu?) (1996)
# 61130       76      1537       5  shall we dance? (shall we dansu?) (1996)
# ...        ...       ...     ...                                       ...
# 61471     6015      1537       3  shall we dance? (shall we dansu?) (1996)
# 61472     6016      1537       5  shall we dance? (shall we dansu?) (1996)
# 61473     6031      1537       4  shall we dance? (shall we dansu?) (1996)
# 61474     6036      1537       4  shall we dance? (shall we dansu?) (1996)
# 61475     6040      1537       5  shall we dance? (shall we dansu?) (1996)
#
#         genre
# 61126  comedy
# 61127  comedy
# 61128  comedy
# 61129  comedy
# 61130  comedy
# ...       ...
# 61471  comedy
# 61472  comedy
# 61473  comedy
# 61474  comedy
# 61475  comedy
#
# [342 rows x 5 columns]

# %% [markdown]
# #### 제가 정한 영화는 아래와 같습니다
# - toy story 2 (1999), chicken run (2000), matrix, the (1999), goodfellas (1990), shall we dance? (shall we dansu?) (1996) 임
# - 해당 영화를 내 취향의 영화라고 가정을 하고, 데이터셋에 추가해주는 작업을 진행함

# %%
ratings3_movie_data.shape
# Out:
# (836478, 5)

# %%
ratings3_movie_data.tail(10)
# Out:
#          user_id  movie_id  counts  \
# 1000197     5334      3323       3
# 1000199     5334      3382       5
# 1000200     5420      1843       3
# 1000201     5433       286       3
# 1000202     5494      3530       4
# 1000203     5556      2198       3
# 1000204     5949      2198       5
# 1000205     5675      2703       3
# 1000207     5851      3607       5
# 1000208     5938      2909       4
#
#                                                title                   genre
# 1000197                        chain of fools (2000)            comedy|crime
# 1000199                       song of freedom (1936)                   drama
# 1000200               slappy and the stinkers (1998)       children's|comedy
# 1000201                     nemesis 2: nebula (1995)  action|sci-fi|thriller
# 1000202                    smoking/no smoking (1993)                  comedy
# 1000203                           modulations (1998)             documentary
# 1000204                           modulations (1998)             documentary
# 1000205                        broken vessels (1998)                   drama
# 1000207                     one little indian (1973)    comedy|drama|western
# 1000208  five wives, three secretaries and me (1998)             documentary

# %%
ratings3_movie_data.user_id.value_counts()
# Out:
# 4169    1968
# 4277    1715
# 1680    1515
# 3618    1146
# 1015    1145
#         ...
# 1102       9
# 4636       9
# 4056       9
# 4349       7
# 4486       1
# Name: user_id, Length: 6039, dtype: int64

# %%
my_favorite = ['toy story 2 (1999)', 'chicken run (2000)', 'matrix, the (1999)', 'goodfellas (1990)', 'shall we dance? (shall we dansu?) (1996)']
favorite_num = [3114, 3751, 2571, 1213, 1537]
my_playlist = pd.DataFrame({'user_id': ['lsh']*5, 'movie_id': favorite_num, 'counts': [5,4,3,5,4]})


if not ratings3_movie_data.isin({'user_id':['lsh']})['user_id'].any():  # user_id에 '6041'라는 데이터가 없다면
    ratings3_movie_data = ratings3_movie_data.append(my_playlist) #my_playlist를 추가해줌

ratings3_movie_data.tail(10)
# Out:
#         user_id  movie_id  counts  \
# 1000203    5556      2198       3
# 1000204    5949      2198       5
# 1000205    5675      2703       3
# 1000207    5851      3607       5
# 1000208    5938      2909       4
# 0           lsh      3114       5
# 1           lsh      3751       4
# 2           lsh      2571       3
# 3           lsh      1213       5
# 4           lsh      1537       4
#
#                                                title                 genre
# 1000203                           modulations (1998)           documentary
# 1000204                           modulations (1998)           documentary
# 1000205                        broken vessels (1998)                 drama
# 1000207                     one little indian (1973)  comedy|drama|western
# 1000208  five wives, three secretaries and me (1998)           documentary
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN

# %% [markdown]
# # 모델에 활용하기 위하여 전처리

# %%
ratings3_movie_data = ratings3_movie_data.reset_index(drop=True)
ratings3_movie_data.tail(10)
# Out:
#        user_id  movie_id  counts                                        title  \
# 836473    5556      2198       3                           modulations (1998)
# 836474    5949      2198       5                           modulations (1998)
# 836475    5675      2703       3                        broken vessels (1998)
# 836476    5851      3607       5                     one little indian (1973)
# 836477    5938      2909       4  five wives, three secretaries and me (1998)
# 836478     lsh      3114       5                                          NaN
# 836479     lsh      3751       4                                          NaN
# 836480     lsh      2571       3                                          NaN
# 836481     lsh      1213       5                                          NaN
# 836482     lsh      1537       4                                          NaN
#
#                        genre
# 836473           documentary
# 836474           documentary
# 836475                 drama
# 836476  comedy|drama|western
# 836477           documentary
# 836478                   NaN
# 836479                   NaN
# 836480                   NaN
# 836481                   NaN
# 836482                   NaN

# %%
# 고유한 유저, 아티스트를 찾아내는 코드
user_unique = ratings3_movie_data['user_id'].unique()
movie_unique = ratings3_movie_data['movie_id'].unique()

# %%
user_to_idx = {v:k for k,v in enumerate(user_unique)}
movie_to_idx = {v:k for k,v in enumerate(movie_unique)}

# %%
print(user_to_idx['lsh'])
print(movie_to_idx[3114])
# Out:
# 6039
# 50

# %%
temp_user_data = ratings3_movie_data['user_id'].map(user_to_idx.get).dropna()
if len(temp_user_data) == len(ratings3_movie_data):   # 모든 row가 정상적으로 인덱싱되었다면
    print('user_id column indexing OK!!')
    ratings3_movie_data['user_id'] = temp_user_data
else:
    print('user_id column indexing Fail!!')

# artist_to_idx을 통해 artist 컬럼도 동일한 방식으로 인덱싱해 줍니다. 
temp_movie_data = ratings3_movie_data['movie_id'].map(movie_to_idx.get).dropna()
if len(temp_movie_data) == len(ratings3_movie_data):
    print('artist column indexing OK!!')
    ratings3_movie_data['movie_id'] = temp_movie_data
else:
    print('artist column indexing Fail!!')

ratings3_movie_data
# Out:
# user_id column indexing OK!!
# artist column indexing OK!!
#         user_id  movie_id  counts                                   title  \
# 0             0         0       5  one flew over the cuckoo's nest (1975)
# 1             1         0       5  one flew over the cuckoo's nest (1975)
# 2             2         0       4  one flew over the cuckoo's nest (1975)
# 3             3         0       4  one flew over the cuckoo's nest (1975)
# 4             4         0       5  one flew over the cuckoo's nest (1975)
# ...         ...       ...     ...                                     ...
# 836478     6039        50       5                                     NaN
# 836479     6039       531       4                                     NaN
# 836480     6039       132       3                                     NaN
# 836481     6039        67       5                                     NaN
# 836482     6039        55       4                                     NaN
#
#         genre
# 0       drama
# 1       drama
# 2       drama
# 3       drama
# 4       drama
# ...       ...
# 836478    NaN
# 836479    NaN
# 836480    NaN
# 836481    NaN
# 836482    NaN
#
# [836483 rows x 5 columns]

# %%
from scipy.sparse import csr_matrix
import numpy as np

# csr_matrix 생성
csr_data = csr_matrix((ratings3_movie_data.counts, (ratings3_movie_data.user_id, ratings3_movie_data.movie_id)), shape=(len(user_unique), len(movie_unique)))

csr_data
# Out:
# <6040x3628 sparse matrix of type '<class 'numpy.int64'>'
# 	with 836483 stored elements in Compressed Sparse Row format>

# %% [markdown]
# - csr_matrix가 잘 생성되었음

# %% [markdown]
# # als_model 구성하기
# 1. factors : 유저와 아이템의 벡터를 몇 차원으로 할 것인지
# 2. regularization : 과적합을 방지하기 위해 정규화 값을 얼마나 사용할 것인지
# 3. use_gpu : GPU를 사용할 것인지
# 4. iterations : epochs와 같은 의미입니다. 데이터를 몇 번 반복해서 학습할 것인지

# %%
als_model = AlternatingLeastSquares(factors=120, regularization=0.01, use_gpu=False, iterations=20, dtype=np.float32)

# %%
#als 모델은 input으로 item X user 꼴의 matrix를 받기 때문에 Transpose해줌
csr_data_transpose = csr_data.T
csr_data_transpose
# Out:
# <3628x6040 sparse matrix of type '<class 'numpy.int64'>'
# 	with 836483 stored elements in Compressed Sparse Column format>

# %%
# 모델 훈련
als_model.fit(csr_data_transpose)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# - 훈련이 완료되었음

# %%
print(ratings3_movie_data.tail(5))
# Out:
#         user_id  movie_id  counts title genre
# 836478     6039        50       5   NaN   NaN
# 836479     6039       531       4   NaN   NaN
# 836480     6039       132       3   NaN   NaN
# 836481     6039        67       5   NaN   NaN
# 836482     6039        55       4   NaN   NaN

# %%
als_model.user_factors[6039]
# Out:
# array([-8.53705183e-02,  5.37052274e-01, -1.12087794e-01,  5.95998466e-01,
#         4.14331138e-01, -6.18317910e-02,  2.71955401e-01, -6.04444206e-01,
#         1.97816446e-01,  3.84320505e-02, -1.19313985e-01, -3.35570127e-01,
#        -3.26557547e-01, -1.44790396e-01,  9.13839817e-01, -7.48380065e-01,
#        -7.20492601e-02,  8.15467298e-01, -1.58641525e-02,  3.57634485e-01,
#         2.44402081e-01,  3.87732778e-03,  7.09041238e-01, -3.04392368e-01,
#        -5.85133135e-01, -1.39939189e-01, -5.80922067e-01, -8.41647908e-02,
#         2.94399969e-02,  2.86483824e-01, -3.79607946e-01,  4.05484557e-01,
#         2.48027429e-01, -1.34701326e-01, -1.01085699e+00,  1.26450256e-01,
#        -1.26676127e-01,  3.82600009e-01, -5.13621449e-01, -4.24090385e-01,
#         5.30969463e-02,  7.60107219e-01, -5.06653726e-01, -6.55268356e-02,
#         9.08387750e-02, -3.19544673e-01,  3.59972447e-01,  9.95329559e-01,
#         1.76201358e-01,  4.29758728e-02, -4.32685196e-01,  3.40098768e-01,
#         6.69364154e-01, -1.20668598e-01,  4.31408584e-01,  3.57040763e-01,
#         4.03145283e-01, -1.85038537e-01, -2.45613158e-01, -6.40271068e-01,
#        -2.62786180e-01,  6.98330104e-01,  1.49602592e-01, -9.78255510e-01,
#         2.44998857e-02,  1.16752066e-01,  2.09049851e-01,  4.40500915e-01,
#         3.85842621e-01, -9.66528803e-02, -3.21804197e-04, -1.42642841e-01,
#         7.01958418e-01,  1.81335509e-01, -3.52375895e-01,  2.51765907e-01,
#        -3.19084972e-01, -2.36774236e-01, -6.61161467e-02,  1.22321695e-01,
#        -1.61117017e-01, -4.93723512e-01,  8.89603257e-01, -2.28915110e-01,
#         8.87846708e-01, -1.97522610e-01,  3.37071210e-01, -3.42662066e-01,
#         6.44748211e-01, -5.76447308e-01, -4.53771688e-02, -7.98747182e-01,
#        -3.03894639e-01,  3.02512765e-01, -2.78672934e-01, -3.39878619e-01,
#        -2.03995004e-01,  3.02673697e-01,  2.96918571e-01,  7.36334085e-01,
#         2.68727422e-01, -1.64144993e-01,  2.99123734e-01,  4.43084240e-01,
#        -6.54969141e-02, -3.35337043e-01, -1.53819267e-02,  2.37389818e-01,
#        -4.84305248e-02, -5.99946417e-02, -1.24757491e-01, -1.97433382e-01,
#        -6.09230101e-01, -6.61085188e-01,  3.72565001e-01, -4.44015622e-01,
#        -3.10901076e-01,  6.05803668e-01,  1.87588017e-03, -6.87963784e-01],
#       dtype=float32)

# %% [markdown]
# - 벡터가 잘 생성된것을 확인할 수 있음

# %%
my_id = als_model.user_factors[6039]
movie1 = als_model.item_factors[50] 
movie2 = als_model.item_factors[531]
movie3 = als_model.item_factors[132]
movie4 = als_model.item_factors[67]
movie5 = als_model.item_factors[55]

# %%
print('toy story2: ', np.dot(my_id, movie1))
print('chicken run: ', np.dot(my_id, movie2))
print('matrix: ', np.dot(my_id, movie3))
print('goodfellas: ', np.dot(my_id, movie4))
print('shall we dance?: ', np.dot(my_id, movie5))
# Out:
# toy story2:  0.7061159
# chicken run:  0.62313414
# matrix:  0.28991598
# goodfellas:  0.40681395
# shall we dance?:  0.30592582

# %%
ratings3_movie_data.loc[ratings3_movie_data['movie_id']==50].iloc[0].title
# Out:
# 'toy story 2 (1999)'

# %%
def movie_names(movie_id):
    movie_name = ratings3_movie_data.loc[ratings3_movie_data['movie_id']==movie_id].iloc[0].title
    return movie_name

# %%
movie_names(50)
# Out:
# 'toy story 2 (1999)'

# %% [markdown]
# - 영화이름이 index로 뽑히기 때문에 영화 이름을 가져오는 함수를 만들어줌

# %% [markdown]
# ## 유사 영화 찾아보기

# %%
similar_movie = als_model.similar_items(50, N=10)
similar_movie[0][1]
# Out:
# 1.0000002

# %%
for i in similar_movie:
    print(i)
# Out:
# (50, 1.0000002)
# (40, 0.7846546)
# (4, 0.6093057)
# (381, 0.3730424)
# (33, 0.3382471)
# (939, 0.33638173)
# (1691, 0.31800535)
# (32, 0.29966077)
# (531, 0.29712594)
# (16, 0.29326802)

# %%
def similary_movie(idx):
    similar_movie = als_model.similar_items(idx, N=10)
    for i in similar_movie:
        print('영화이름:{}, 유사도:{}'.format(movie_names(i[0]),round(i[1],3)))

# %% [markdown]
# - 유사 영화를 찾아주는 함수를 만들어줌

# %%
similary_movie(50)
# Out:
# 영화이름:toy story 2 (1999), 유사도:1.0
# 영화이름:toy story (1995), 유사도:0.7850000262260437
# 영화이름:bug's life, a (1998), 유사도:0.609000027179718
# 영화이름:babe (1995), 유사도:0.37299999594688416
# 영화이름:aladdin (1992), 유사도:0.33799999952316284
# 영화이름:iron giant, the (1999), 유사도:0.335999995470047
# 영화이름:stuart little (1999), 유사도:0.3179999887943268
# 영화이름:hercules (1997), 유사도:0.30000001192092896
# 영화이름:chicken run (2000), 유사도:0.296999990940094
# 영화이름:tarzan (1999), 유사도:0.2930000126361847

# %% [markdown]
# - toy story 2와 유사한 영화를 찾아서 보여줌
# - toy story1, chicken run, tarzan 같은 유사 영화가 존재함

# %% [markdown]
# ## 영화 추천 받기

# %%
movie_recommended = als_model.recommend(6039, csr_data, N=10, filter_already_liked_items=True)
movie_recommended
# Out:
# [(40, 0.48182172),
#  (244, 0.34726202),
#  (4, 0.32908463),
#  (167, 0.28031832),
#  (259, 0.27252793),
#  (51, 0.2690822),
#  (381, 0.24837357),
#  (128, 0.24043323),
#  (97, 0.2320743),
#  (336, 0.21587679)]

# %%
def recommended_movie(idx):
    movie_recommended = als_model.recommend(idx, csr_data, N=10, filter_already_liked_items=True)

    for i in movie_recommended:
        print('영화이름:{}, 추천도:{}'.format(movie_names(i[0]),round(i[1],3)))

# %%
recommended_movie(6039)
# Out:
# 영화이름:toy story (1995), 추천도:0.4819999933242798
# 영화이름:pulp fiction (1994), 추천도:0.34700000286102295
# 영화이름:bug's life, a (1998), 추천도:0.32899999618530273
# 영화이름:shawshank redemption, the (1994), 추천도:0.2800000011920929
# 영화이름:usual suspects, the (1995), 추천도:0.27300000190734863
# 영화이름:fargo (1996), 추천도:0.26899999380111694
# 영화이름:babe (1995), 추천도:0.24799999594688416
# 영화이름:silence of the lambs, the (1991), 추천도:0.23999999463558197
# 영화이름:terminator 2: judgment day (1991), 추천도:0.23199999332427979
# 영화이름:reservoir dogs (1992), 추천도:0.2160000056028366

# %% [markdown]
# - shawshank redemption, the, pulp fiction와 같은 범죄/드라마 장르의 영화를 추천해주는것을 알 수 있음
# - 실제로도 범죄/스릴러/드라마 같은 장르를 좋아하기 때문에 개인적으로는 좋은 추천이라고 생각됨

# %% [markdown]
# ## 기여도 확인해보기
# - pulp fiction를 추천해준 이유에 대해 알아보기

# %%
explain = als_model.explain(6039, csr_data, itemid=244)
explain
# Out:
# (0.34361756566292256,
#  [(67, 0.3074363547165795),
#   (132, 0.014215865124967492),
#   (55, 0.01243762249240068),
#   (50, 0.005882047720603415),
#   (531, 0.003645675608371532)],
#  (array([[ 6.00193867e-01,  1.23686119e-01,  8.10714842e-02, ...,
#            9.87894867e-02,  9.71732537e-02,  1.20545832e-01],
#          [ 7.42356500e-02,  6.15568561e-01,  6.32009086e-02, ...,
#            1.32234950e-01,  9.83889347e-02,  9.77875860e-02],
#          [ 4.86586076e-02,  4.89319096e-02,  5.88962401e-01, ...,
#            8.72844593e-02,  7.69917355e-02,  3.64148010e-02],
#          ...,
#          [ 5.92928440e-02,  9.36185661e-02,  6.77736440e-02, ...,
#            5.49947181e-01, -3.56868894e-04, -1.71177138e-02],
#          [ 5.83227909e-02,  7.25841175e-02,  5.94414873e-02, ...,
#            6.53323349e-02,  5.29021341e-01,  5.99522758e-03],
#          [ 7.23508689e-02,  7.51048097e-02,  3.74000424e-02, ...,
#            5.58156405e-02,  7.05960748e-02,  5.36210666e-01]]),
#   False))

# %%
explain[1]
# Out:
# [(67, 0.3074363547165795),
#  (132, 0.014215865124967492),
#  (55, 0.01243762249240068),
#  (50, 0.005882047720603415),
#  (531, 0.003645675608371532)]

# %%
def contribution_movie(user, movie_idx):
    explain = als_model.explain(user, csr_data, itemid=movie_idx)
    explain1 = explain[1]
    
    for i in explain1:
        print('영화이름:{}, 기여도:{}'.format(movie_names(i[0]),round(i[1],3)))

# %%
contribution_movie(6039, 244)
# Out:
# 영화이름:goodfellas (1990), 기여도:0.307
# 영화이름:matrix, the (1999), 기여도:0.014
# 영화이름:shall we dance? (shall we dansu?) (1996), 기여도:0.012
# 영화이름:toy story 2 (1999), 기여도:0.006
# 영화이름:chicken run (2000), 기여도:0.004

# %% [markdown]
# - pulp fiction를 추천해준 이유는 goodfellas라는 영화를 선호했기 때문이란것을 알 수 있음
# - 두 영화는 모두 범죄/드라마물로서 관객이 비슷한 장르의 영화를 좋아할것이라 생각하고 추천해준다는것을 알 수 있음

# %% [markdown]
# # 전체 회고
# - 생각보다 어렵지는 않은 노드였다고 생각된다.
# - 하지만 crs_matrix를 만들때 index값이 안맞아서 오류가 생겼던것 말고는 잘 해결됐다.
# - 추천 받은 영화도 내가 관심있었던 장르로 추천을 해줘서 의미있는 crs_matrix가 만들어진것 같다고 생각된다.

# %% [markdown]
# # 참고자료
# - https://bkshin.tistory.com/entry/NLP-7-%ED%9D%AC%EC%86%8C-%ED%96%89%EB%A0%AC-Sparse-Matrix-COO-%ED%98%95%EC%8B%9D-CSR-%ED%98%95%EC%8B%9D
# - https://lsjsj92.tistory.com/569
